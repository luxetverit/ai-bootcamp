# %% [markdown]
# # 1. 데이터 분석 개요

# %% [markdown]
# ## Step 1: 질문하기 (Ask questions)
# 데이터가 주어진 상태에서 질문을 할 수도 있고, 질문에 답할 수 있는 데이터를 수집할 수도 있다.

# %% [markdown]
# ## Step 2: 데이터 랭글링 (Wrangle data)
# - 데이터 랭글링 : 원자료(raw data)를 보다 쉽게 접근하고 분석할 수 있도록 데이터를 정리하고 통합하는 과정
# (참고. 위키피디아)
# - 세부적으로는 데이터의 수집(gather), 평가(assess), 정제(clean) 작업으로 나눌 수 있다.

# %% [markdown]
# ## Step 3: 데이터 탐색 (Exploratory Data Analysis)
# 데이터의 패턴을 찾고, 관계를 시각화 하는 작업을 통해 데이터에 대한 직관을 극대화 한다.

# %% [markdown]
# ## Step 4: 결론 도출 또는 예측 (Draw conclusions or make predictions)
# - Step 3에서 분석한 내용을 근거로 질문에 대한 답과 결론을 도출 할 수 있다.
# - 머신러닝 또는 통계 추정 과정을 거치게 되면 예측을 만들어 낼 수도 있다.

# %% [markdown]
# ## Step 5: 결과 공유 (Communicate the results)
# 보고서, 이메일, 블로그 등 다양한 방법을 통해 발견한 통찰들을 공유할 수 있다.

# %% [markdown]
# # 2. Case Study

# %% [markdown]
# ## Bike Sharing Demand

# %% [markdown]
# - 도시 자전거 공유 시스템 사용 예측
# - [캐글](https://www.kaggle.com)의 [Bike Sharing Demand](https://www.kaggle.com/c/bike-sharing-demand)에서 `train.csv`와 `test.csv`를 다운로드
# - 두 파일을 각각 datasets 디렉토리에 bike_train.csv bike_test.csv로 저장

# %% [markdown]
# **datetime** : hourly date + timestamp
# **season** : 1 = 봄, 2 = 여름, 3 = 가을, 4 = 겨울
# **holiday**: 1 = 토, 일요일의 주말을 제외한 국경일 등의 휴일, 0 = 휴일이 아닌 날
# **workingday**: 1 = 토, 일요일의 주말 및 휴일이 아닌 주중, 0 = 주말 및 휴일
# **weather**:
# - 1 = 맑음, 약간 구름 낀 흐림
# - 2 = 안개, 안개 + 흐림
# - 3 = 가벼운 눈, 가벼운 비 + 천둥
# - 4 = 심한 눈/비, 천둥/번개
#
# **temp**: 온도(섭씨)
# **atemp**: 체감온도(섭씨)
# **humidity**: 상대습도
# **windspeed**: 풍속
# **casual**: 사전에 등록되지 않는 사용자가 대여한 횟수
# **registered**: 사전에 등록된 사용자가 대여한 횟수
# **count**: 대여 횟수

# %% [markdown]
# ## Step 1: 질문하기 (Ask questions)

# %% [markdown]
#  **예시**
#  - 질문1 : 기상정보에 따른 대여량 차이
#  - 질문2 : 요일별 대여현황
#  - 질문3 : 등록된 사용자와 등록되지 않은 사용자의 주말 대여 그래프 비교
#  - 질문4 : 프로모션 기간 설정
#  -

# %% [markdown]
# ## Step 2: 데이터 랭글링 (Wrangle data)

# %% [markdown]
# - 데이터 적재

# %%
import pandas as pd

# %%
# dataframe = pd.read_csv(filename)
bike = pd.read_csv('./dataset/train.csv')

# %% [markdown]
# - 데이터 평가

# %%
bike.head()
# Out:
#               datetime  season  holiday  workingday  weather  temp   atemp  \
# 0  2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 1  2011-01-01 01:00:00       1        0           0        1  9.02  13.635
# 2  2011-01-01 02:00:00       1        0           0        1  9.02  13.635
# 3  2011-01-01 03:00:00       1        0           0        1  9.84  14.395
# 4  2011-01-01 04:00:00       1        0           0        1  9.84  14.395
#
#    humidity  windspeed  casual  registered  count
# 0        81        0.0       3          13     16
# 1        80        0.0       8          32     40
# 2        80        0.0       5          27     32
# 3        75        0.0       3          10     13
# 4        75        0.0       0           1      1

# %%
bike.info() #데이터 타입, 데이터 누락, 총 컬럼, 총row
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10886 entries, 0 to 10885
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   datetime    10886 non-null  object
#  1   season      10886 non-null  int64
#  2   holiday     10886 non-null  int64
#  3   workingday  10886 non-null  int64
#  4   weather     10886 non-null  int64
#  5   temp        10886 non-null  float64
#  6   atemp       10886 non-null  float64
#  7   humidity    10886 non-null  int64
#  8   windspeed   10886 non-null  float64
#  9   casual      10886 non-null  int64
#  10  registered  10886 non-null  int64
#  11  count       10886 non-null  int64
# dtypes: float64(3), int64(8), object(1)
# memory usage: 1020.7+ KB

# %% [markdown]
# - 데이터 정제 (누락된 값 처리, 잘못된 데이터 타입)

# %%
bike.datetime # bike 데이터 datetime 열의 값
# Out:
# 0        2011-01-01 00:00:00
# 1        2011-01-01 01:00:00
# 2        2011-01-01 02:00:00
# 3        2011-01-01 03:00:00
# 4        2011-01-01 04:00:00
#                 ...
# 10881    2012-12-19 19:00:00
# 10882    2012-12-19 20:00:00
# 10883    2012-12-19 21:00:00
# 10884    2012-12-19 22:00:00
# 10885    2012-12-19 23:00:00
# Name: datetime, Length: 10886, dtype: object

# %%
bike['datetime'] # bike 데이터 datetime 열의 값
# Out:
# 0        2011-01-01 00:00:00
# 1        2011-01-01 01:00:00
# 2        2011-01-01 02:00:00
# 3        2011-01-01 03:00:00
# 4        2011-01-01 04:00:00
#                 ...
# 10881    2012-12-19 19:00:00
# 10882    2012-12-19 20:00:00
# 10883    2012-12-19 21:00:00
# 10884    2012-12-19 22:00:00
# 10885    2012-12-19 23:00:00
# Name: datetime, Length: 10886, dtype: object

# %%
bike['datetime'] = bike['datetime'].apply(pd.to_datetime)

# %%
bike['year'] = bike['datetime'].apply(lambda x : x.year)

# %%
bike['month'] = bike['datetime'].apply(lambda x : x.month)
bike['dayofweek'] = bike['datetime'].apply(lambda x : x.dayofweek)

# %%
bike.head()
# Out:
#              datetime  season  holiday  workingday  weather  temp   atemp  \
# 0 2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 1 2011-01-01 01:00:00       1        0           0        1  9.02  13.635
# 2 2011-01-01 02:00:00       1        0           0        1  9.02  13.635
# 3 2011-01-01 03:00:00       1        0           0        1  9.84  14.395
# 4 2011-01-01 04:00:00       1        0           0        1  9.84  14.395
#
#    humidity  windspeed  casual  registered  count  year  month  dayofweek
# 0        81        0.0       3          13     16  2011      1          5
# 1        80        0.0       8          32     40  2011      1          5
# 2        80        0.0       5          27     32  2011      1          5
# 3        75        0.0       3          10     13  2011      1          5
# 4        75        0.0       0           1      1  2011      1          5

# %%
bike.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10886 entries, 0 to 10885
# Data columns (total 15 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   datetime    10886 non-null  datetime64[ns]
#  1   season      10886 non-null  int64
#  2   holiday     10886 non-null  int64
#  3   workingday  10886 non-null  int64
#  4   weather     10886 non-null  int64
#  5   temp        10886 non-null  float64
#  6   atemp       10886 non-null  float64
#  7   humidity    10886 non-null  int64
#  8   windspeed   10886 non-null  float64
#  9   casual      10886 non-null  int64
#  10  registered  10886 non-null  int64
#  11  count       10886 non-null  int64
#  12  year        10886 non-null  int64
#  13  month       10886 non-null  int64
#  14  dayofweek   10886 non-null  int64
# dtypes: datetime64[ns](1), float64(3), int64(11)
# memory usage: 1.2 MB

# %% [markdown]
# ## Step 3: 데이터 탐색 (Exploratory Data Analysis)

# %% [markdown]
#  - 기상정보(온도, 체감온도, 풍속, 습도)와 자전거 대여량의 관계

# %%
bike.plot(kind = 'scatter', x='temp', y='count', alpha=0.3)
# Out:
# <AxesSubplot:xlabel='temp', ylabel='count'>

# %%
import matplotlib.pyplot as plt

# %%
fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(16, 10))
# axes = 실질적인 축을 의미(row2개, col2개 즉 총 4개, figsize = 가로세로 사이즈)

axes[0][0].scatter(bike['temp'], bike['count'], alpha = 0.1)
axes[0][1].scatter(bike['atemp'], bike['count'], alpha = 0.1)
axes[1][0].scatter(bike['humidity'], bike['count'], alpha = 0.1)
axes[1][1].scatter(bike['windspeed'], bike['count'], alpha = 0.1)

# %% [markdown]
#  - 상관계수 : 산정도를 통해 나온 결과를 수치화된 데이터로 알려줌

# %%
bike.corr()
# Out:
#               season   holiday  workingday   weather      temp     atemp  \
# season      1.000000  0.029368   -0.008126  0.008879  0.258689  0.264744
# holiday     0.029368  1.000000   -0.250491 -0.007074  0.000295 -0.005215
# workingday -0.008126 -0.250491    1.000000  0.033772  0.029966  0.024660
# weather     0.008879 -0.007074    0.033772  1.000000 -0.055035 -0.055376
# temp        0.258689  0.000295    0.029966 -0.055035  1.000000  0.984948
# atemp       0.264744 -0.005215    0.024660 -0.055376  0.984948  1.000000
# humidity    0.190610  0.001929   -0.010880  0.406244 -0.064949 -0.043536
# windspeed  -0.147121  0.008409    0.013373  0.007261 -0.017852 -0.057473
# casual      0.096758  0.043799   -0.319111 -0.135918  0.467097  0.462067
# registered  0.164011 -0.020956    0.119460 -0.109340  0.318571  0.314635
# count       0.163439 -0.005393    0.011594 -0.128655  0.394454  0.389784
# year       -0.004797  0.012021   -0.002482 -0.012548  0.061226  0.058540
# month       0.971524  0.001731   -0.003394  0.012144  0.257589  0.264173
# dayofweek  -0.010553 -0.191832   -0.704267 -0.047692 -0.038466 -0.040235
#
#             humidity  windspeed    casual  registered     count      year  \
# season      0.190610  -0.147121  0.096758    0.164011  0.163439 -0.004797
# holiday     0.001929   0.008409  0.043799   -0.020956 -0.005393  0.012021
# workingday -0.010880   0.013373 -0.319111    0.119460  0.011594 -0.002482
# weather     0.406244   0.007261 -0.135918   -0.109340 -0.128655 -0.012548
# temp       -0.064949  -0.017852  0.467097    0.318571  0.394454  0.061226
# atemp      -0.043536  -0.057473  0.462067    0.314635  0.389784  0.058540
# humidity    1.000000  -0.318607 -0.348187   -0.265458 -0.317371 -0.078606
# windspeed  -0.318607   1.000000  0.092276    0.091052  0.101369 -0.015221
# casual     -0.348187   0.092276  1.000000    0.497250  0.690414  0.145241
# registered -0.265458   0.091052  0.497250    1.000000  0.970948  0.264265
# count      -0.317371   0.101369  0.690414    0.970948  1.000000  0.260403
# year       -0.078606  -0.015221  0.145241    0.264265  0.260403  1.000000
# month       0.204537  -0.150192  0.092722    0.169451  0.166862 -0.004932
# dayofweek  -0.026507  -0.024804  0.246959   -0.084427 -0.002283 -0.003785
#
#                month  dayofweek
# season      0.971524  -0.010553
# holiday     0.001731  -0.191832
# workingday -0.003394  -0.704267
# weather     0.012144  -0.047692
# temp        0.257589  -0.038466
# atemp       0.264173  -0.040235
# humidity    0.204537  -0.026507
# windspeed  -0.150192  -0.024804
# casual      0.092722   0.246959
# registered  0.169451  -0.084427
# count       0.166862  -0.002283
# year       -0.004932  -0.003785
# month       1.000000  -0.002266
# dayofweek  -0.002266   1.000000

# %% [markdown]
# **분석**
#  - 기상 정보 중 온도와 체감온도가 자전거 대여 수량에 영향을 미칠것으로 보임
#     (산정도, 상관계수)

# %% [markdown]
# **참고**
#  - year, month, hour, dayofweek 특성에 따른 대여량 --> 범주형 데이터(패션 아이템의 카테고리 같은것들, 결과는 카테고리 내에서만 나온다)
#  - count --> 수치형 데이터(자전거 대여량, 범위가 정해져 있지 않음)
#  - 범주형 데이터 값에 따라 수치형 데이터가 어떻게 달라지는지 파악할 때 막대 그래프가 유용

# %%
import seaborn as sns

# %% [markdown]
# **분석2**

# %% [markdown]
# ## Step 4: 결론 도출 또는 예측 (Draw conclusions or make predictions)

# %% [markdown]
# ## Step 5: 결과 공유 (Communicate the results)
